# %%
import pandas as pd

# %%
df = pd.read_csv('kepler.csv')
df = df[['kepler_name','koi_score','koi_period','koi_prad','koi_teq','koi_slogg','koi_srad']]

# %%
df = df[df['kepler_name'].notna()]

# %%
df = df[df['koi_score'].notna()]

# %%
df
# Out:
#         kepler_name  koi_score  koi_period  koi_prad  koi_teq  koi_slogg  \
# 0      Kepler-227 b      1.000    9.488036      2.26    793.0      4.467
# 1      Kepler-227 c      0.969   54.418383      2.83    443.0      4.467
# 4      Kepler-664 b      1.000    2.525592      2.75   1406.0      4.438
# 5      Kepler-228 d      1.000   11.094321      3.90    835.0      4.486
# 6      Kepler-228 c      1.000    4.134435      2.77   1160.0      4.486
# ...             ...        ...         ...       ...      ...        ...
# 7612  Kepler-1482 b      1.000   12.253843      1.00    678.0      4.579
# 7658    Kepler-90 f      0.995  124.922516      3.37    407.0      4.317
# 8817  Kepler-1646 b      1.000    4.485592      0.95    365.0      5.097
# 9014   Kepler-452 b      0.771  384.847556      1.09    220.0      4.580
# 9083  Kepler-1629 b      0.000    3.875943      0.68   1081.0      4.541
#
#       koi_srad
# 0        0.927
# 1        0.927
# 4        1.046
# 5        0.972
# ...

# %%
df.columns=['name','confidence','period','radius','temperature','gravity','star size']

# %%
df_num = df.iloc[:,1:]

# %%
df_num
# Out:
#       confidence      period  radius  temperature  gravity  star size
# 0          1.000    9.488036    2.26        793.0    4.467      0.927
# 1          0.969   54.418383    2.83        443.0    4.467      0.927
# 4          1.000    2.525592    2.75       1406.0    4.438      1.046
# 5          1.000   11.094321    3.90        835.0    4.486      0.972
# 6          1.000    4.134435    2.77       1160.0    4.486      0.972
# ...          ...         ...     ...          ...      ...        ...
# 7612       1.000   12.253843    1.00        678.0    4.579      0.820
# 7658       0.995  124.922516    3.37        407.0    4.317      1.200
# 8817       1.000    4.485592    0.95        365.0    5.097      0.193
# 9014       0.771  384.847556    1.09        220.0    4.580      0.798
# 9083       0.000    3.875943    0.68       1081.0    4.541      0.893
#
# [2348 rows x 6 columns]

# %%
df_name = df[df['kepler_name'].notna()]

# %%
df2 = df_name[df_name['koi_disposition'] == 'CONFIRMED']

# %%
df3 = df2[df2['koi_pdisposition'] == 'CANDIDATE']

# %%
df3
# Out:
#          kepid kepoi_name    kepler_name koi_disposition koi_pdisposition  \
# 0     10797460  K00752.01   Kepler-227 b       CONFIRMED        CANDIDATE
# 1     10797460  K00752.02   Kepler-227 c       CONFIRMED        CANDIDATE
# 4     10854555  K00755.01   Kepler-664 b       CONFIRMED        CANDIDATE
# 5     10872983  K00756.01   Kepler-228 d       CONFIRMED        CANDIDATE
# 6     10872983  K00756.02   Kepler-228 c       CONFIRMED        CANDIDATE
# ...        ...        ...            ...             ...              ...
# 7658  11442793  K00351.07    Kepler-90 f       CONFIRMED        CANDIDATE
# 8817   7350067  K06863.01  Kepler-1646 b       CONFIRMED        CANDIDATE
# 8956   9730163  K02704.03   Kepler-445 d       CONFIRMED        CANDIDATE
# 9014   8311864  K07016.01   Kepler-452 b       CONFIRMED        CANDIDATE
# 9083   7935997  K05447.02  Kepler-1629 b       CONFIRMED        CANDIDATE
#
#       koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# ...
